# %% [markdown]
# ## Проверка функции, угадывающей число менее чем за 20 попыток

# %%
from evaluation_function import score_game
from game_core_v3 import game_core_v3
score_game(game_core_v3)
# Out:
# Ваш алгоритм угадывает число в среднем за: 10 попытки
